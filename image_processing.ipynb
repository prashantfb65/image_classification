# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread('data/00-puppy.jpg')

# %%
plt.imshow(img)
# Matplotlib --> RGB
# OpenCV --> GBR

# %%
fix_img = cv2.cvtColor(img, cv2.COLORGBR)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-624e50f2cdf4> in <module>
# ----> 1 fix_img = cv2.cvtColor(img, cv2.COLOR_BAYER_BG2RGB)
#
# error: OpenCV(4.1.1) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/demosaicing.cpp:1700: error: (-215:Assertion failed) scn == 1 && (dcn == 3 || dcn == 4) in function 'demosaicing'
